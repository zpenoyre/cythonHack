# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %load_ext Cython
# line profiler prints line by line timings, more details here
# http://mortada.net/easily-profile-python-code-in-jupyter.html
# and for use with cython, here
# http://nbviewer.jupyter.org/gist/tillahoffmann/296501acea231cbdf5e7
# %load_ext line_profiler

# %%
#this allows line profiler (via ipython magic %lprun) to profile cython functions
from Cython.Compiler.Options import get_directive_defaults

get_directive_defaults()['linetrace'] = True
get_directive_defaults()['binding'] = True

# %%
# %%cython -a -f --compile-args=-DCYTHON_TRACE=1
# import numpy as np
# cimport numpy as np
# from __main__ import plotSim
#
# from libcpp.vector cimport vector
#
# cdef vector[particleClass] particles
# cdef double boxSize
# cdef double dt
#
# #simulation variables stored globally in cython and updateable from python via these functions
# cpdef updateBoxSize(double newSize):
#     global boxSize
#     boxSize=newSize
# cpdef updateDt(double newDt):
#     global dt
#     dt=newDt
#
# cdef struct particleClass:
#     double[3] pos,vel,acc
#     double m
#     int index
#
# def getX(whichP):
#     return np.asarray(particles[whichP].pos)
# def getV(whichP):
#     return np.asarray(particles[whichP].vel)
# def updateX(whichP):
#     for count in range(3):
#         particles[whichP].pos[count]=(particles[whichP].pos[count]
#                                       + particles[whichP].vel[count]*dt) % boxSize
# def updateV(whichP):
#     for count in range(3):
#         particles[whichP].vel[count] = particles[whichP].vel[count] + particles[whichP].acc[count]*dt
#
# def updateA(whichP):
#     findAcc(whichP)
#
# cpdef void initSim(nParticles):
#     cdef particleClass newP
#     pMass=1 #mass of each particle
#     global particles
#     particles.clear()
#     for i in range(nParticles):
#         newP.index=i
#         newP.pos=boxSize*np.random.random(3)
#         newP.vel=boxSize*np.sign(1-2*np.random.random(3)) # units be damned...
#         newP.m=pMass
#         particles.push_back(newP)
#
# def runSim(endTime,nPlots): #simple leapfrog integration
#     nTimestep=int(endTime/dt)
#     for i in range(nTimestep):
#         for i in particles.size(): #to do leapfrog integration you need to update all positions
#             updateX(i)
#         for i in particles.size(): #then compute new accelerations on the evolved system
#             updateA(i)
#             updateV(i)
#         if (i%int(nTimestep/nPlots)==0): #periodically plots the state of the box
#             plotSim(particles,i*dt,i/int(nTimestep/nPlots))
#
# cdef void findAcc(int thisP):
#     cdef:
#         double[3] pos=particles[thisP].pos, particlePos, acc=np.zeros(3,dtype=float), r_vect=np.zeros(3,dtype=float)
#         double particleMass,factor,r=0,dx=0
#         int i,whichP,nP=len(particles)
#         particleClass p
#     for whichP in range(nP):
#         p=particles[whichP]
#         particlePos=p.pos
#         particleMass=p.m
#
#         r=0
#         for i in range(3): #checks periodic boundary conditions
#             dx=pos[i]-particlePos[i]
#             if (dx > boxSize/2):
#                 dx-=boxSize
#             elif (dx < -boxSize/2):
#                 dx+=boxSize
#             r+=dx**2
#             r_vect[i]=dx
#         if (r==0): # the particle should feel no force from itself
#             continue
#         r=r**0.5+0.1 #0.1 is gravitational softening length
#
#         factor=(-particleMass/r**3) #0.1 is gravitational softening length
#         for i in range(3):
#             acc[i]+=factor*r_vect[i] # == GM/r^3 _r_ in units where G=1
#     particles[thisP].acc= acc
# Out:
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# /Users/Zephyr/Astro/anaconda/lib/python3.5/distutils/unixccompiler.py in _compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     117             self.spawn(compiler_so + cc_args + [src, '-o', obj] +
# --> 118                        extra_postargs)
#     119         except DistutilsExecError as msg:
#
# /Users/Zephyr/Astro/anaconda/lib/python3.5/distutils/ccompiler.py in spawn(self, cmd)
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#
# /Users/Zephyr/Astro/anaconda/lib/python3.5/distutils/spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      35     if os.name == 'posix':
# ---> 36         _spawn_posix(cmd, search_path, dry_run=dry_run)
#      37     elif os.name == 'nt':
#
# ...

# %%
def plotSim(particles,time,whichPlot):
    fig1=plt.subplot(grid[int(whichPlot),0])
    fig1.set_xlim(0,boxSize)
    fig1.set_ylim(0,boxSize)
    fig1.set_xlabel("x")
    fig1.set_ylabel("y")
    fig1.set_title('t='+str(time))
    v=np.zeros(len(particles))
    for i,p in enumerate(particles):
        pos=p.getX()
        fig1.scatter(pos[0],pos[1],color=cmap(p.index/nParticles),s=1)
        #optionally add velocities, currently not very readable
        #fig1.quiver(p.pos[0],p.pos[1],p.vel[0],p.vel[1])
        v[i]=np.linalg.norm(p.getV())
    fig2=plt.subplot(grid[int(whichPlot),1])
    maxV=5*np.mean(v)
    nBin=20
    fig2.set_xlim(0,maxV)
    fig2.hist(v,bins=nBin,range=(0,maxV),color=cmap(0.7),edgecolor=cmap(0.7))
    fig2.set_xlabel("v")
    fig2.set_ylabel("n(v)")

# %%
nParticles=500
boxSize=10
dt=0.25 # in units where G=1
endTime=50
# in these units it takes roughly t=80 for two particles of mass 1 
# to cross corner to corner of boxSize=10 and come to rest

nPlots=4
plots=plt.figure(figsize=(8,nPlots*4))
grid=matplotlib.gridspec.GridSpec(nPlots,2)
cmap=matplotlib.cm.get_cmap('Set2')

updateBoxSize(boxSize)
updateDt(dt)
initSim(nParticles)
# %lprun will analyse a particular funtion (i.e. "-f functionName")
# WITHIN your funtion call (doesn't work on cdef functions)
#%lprun -f runSim runSim(boxSize,dt,endTime,nPlots)

# %prun does timing function by function (works fine with cdef)
#%prun runSim(endTime,nPlots)

# most reliable timing method (%timeit's also good)
import time
tThen = time.time()
runSim(endTime,nPlots)
print(time.time()-tThen)

plt.show()
# Out:
# 6.034348964691162
